# %%
# %matplotlib inline

# %%
import time
import datetime
import requests as rq
import csv
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from time import sleep

# %%
hero_stat_url = "https://api.opendota.com/api/heroStats"
r = rq.get(hero_stat_url)
r.json()
# Out:
# [{'1000_pick': 13074,
#   '1000_win': 6732,
#   '2000_pick': 31602,
#   '2000_win': 16553,
#   '3000_pick': 39697,
#   '3000_win': 20893,
#   '4000_pick': 13239,
#   '4000_win': 6843,
#   '5000_pick': 1973,
#   '5000_win': 1009,
#   'agi_gain': 2.8,
#   'attack_range': 150,
#   'attack_rate': 1.45,
#   'attack_type': 'Melee',
#   'base_agi': 22,
#   'base_armor': -1,
#   'base_attack_max': 31,
#   'base_attack_min': 27,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 12,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 22,
#   'cm_enabled': True,
#   'hero_id': 1,
#   'icon': '/apps/dota2/images/heroes/antimage_icon.png',
#   'id': 1,
#   'img': '/apps/dota2/images/heroes/antimage_full.png?',
#   'int_gain': 1.8,
#   'legs': 2,
#   'localized_name': 'Anti-Mage',
#   'move_speed': 310,
#   'name': 'npc_dota_hero_antimage',
#   'primary_attr': 'agi',
#   'pro_ban': 230,
#   'pro_pick': 86,
#   'pro_win': 45,
#   'projectile_speed': 0,
#   'roles': ['Carry', 'Escape', 'Nuker'],
#   'str_gain': 1.3,
#   'turn_rate': 0.5},
#  {'1000_pick': 9883,
#   '1000_win': 5274,
#   '2000_pick': 20019,
#   '2000_win': 10418,
#   '3000_pick': 20695,
#   '3000_win': 10656,
#   '4000_pick': 5512,
#   '4000_win': 2795,
#   '5000_pick': 625,
#   '5000_win': 283,
#   'agi_gain': 2.2,
#   'attack_range': 150,
#   'attack_rate': 1.7,
#   'attack_type': 'Melee',
#   'base_agi': 20,
#   'base_armor': -1,
#   'base_attack_max': 28,
#   'base_attack_min': 24,
#   'base_health': 200,
#   'base_health_regen': 4.25,
#   'base_int': 18,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 25,
#   'cm_enabled': True,
#   'hero_id': 2,
#   'icon': '/apps/dota2/images/heroes/axe_icon.png',
#   'id': 2,
#   'img': '/apps/dota2/images/heroes/axe_full.png?',
#   'int_gain': 1.6,
#   'legs': 2,
#   'localized_name': 'Axe',
#   'move_speed': 290,
#   'name': 'npc_dota_hero_axe',
#   'primary_attr': 'str',
#   'pro_ban': 13,
#   'pro_pick': 20,
#   'pro_win': 11,
#   'projectile_speed': 900,
#   'roles': ['Initiator', 'Durable', 'Disabler', 'Jungler'],
#   'str_gain': 2.8,
#   'turn_rate': 0.6},
#  {'1000_pick': 2747,
#   '1000_win': 1250,
#   '2000_pick': 7009,
#   '2000_win': 3260,
#   '3000_pick': 9398,
#   '3000_win': 4478,
#   '4000_pick': 3496,
#   '4000_win': 1735,
#   '5000_pick': 764,
#   '5000_win': 381,
#   'agi_gain': 2.4,
#   'attack_range': 400,
#   'attack_rate': 1.7,
#   'attack_type': 'Ranged',
#   'base_agi': 23,
#   'base_armor': 1,
#   'base_attack_max': 43,
#   'base_attack_min': 37,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 23,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 23,
#   'cm_enabled': True,
#   'hero_id': 3,
#   'icon': '/apps/dota2/images/heroes/bane_icon.png',
#   'id': 3,
#   'img': '/apps/dota2/images/heroes/bane_full.png?',
#   'int_gain': 2.4,
#   'legs': 4,
#   'localized_name': 'Bane',
#   'move_speed': 310,
#   'name': 'npc_dota_hero_bane',
#   'primary_attr': 'int',
#   'pro_ban': 252,
#   'pro_pick': 160,
#   'pro_win': 85,
#   'projectile_speed': 900,
#   'roles': ['Support', 'Disabler', 'Nuker', 'Durable'],
#   'str_gain': 2.4,
#   'turn_rate': 0.6},
#  {'1000_pick': 12548,
#   '1000_win': 6472,
#   '2000_pick': 24101,
#   '2000_win': 12746,
#   '3000_pick': 25088,
#   '3000_win': 13052,
#   '4000_pick': 7659,
#   '4000_win': 3963,
#   '5000_pick': 1277,
#   '5000_win': 645,
#   'agi_gain': 3,
#   'attack_range': 150,
#   'attack_rate': 1.7,
#   'attack_type': 'Melee',
#   'base_agi': 24,
#   'base_armor': 0,
#   'base_attack_max': 39,
#   'base_attack_min': 33,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 18,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 23,
#   'cm_enabled': True,
#   'hero_id': 4,
#   'icon': '/apps/dota2/images/heroes/bloodseeker_icon.png',
#   'id': 4,
#   'img': '/apps/dota2/images/heroes/bloodseeker_full.png?',
#   'int_gain': 1.7,
#   'legs': 2,
#   'localized_name': 'Bloodseeker',
#   'move_speed': 285,
#   'name': 'npc_dota_hero_bloodseeker',
#   'primary_attr': 'agi',
#   'pro_ban': 151,
#   'pro_pick': 83,
#   'pro_win': 43,
#   'projectile_speed': 900,
#   'roles': ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Initiator'],
#   'str_gain': 2.7,
#   'turn_rate': 0.5},
#  {'1000_pick': 7574,
#   '1000_win': 4236,
#   '2000_pick': 17354,
#   '2000_win': 9480,
#   '3000_pick': 20525,
#   '3000_win': 10845,
#   '4000_pick': 6395,
#   '4000_win': 3265,
#   '5000_pick': 725,
#   '5000_win': 353,
#   'agi_gain': 1.6,
#   'attack_range': 600,
#   'attack_rate': 1.7,
#   'attack_type': 'Ranged',
#   'base_agi': 16,
#   'base_armor': -1,
#   'base_attack_max': 25,
#   'base_attack_min': 19,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 16,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 16,
#   'cm_enabled': True,
#   'hero_id': 5,
#   'icon': '/apps/dota2/images/heroes/crystal_maiden_icon.png',
#   'id': 5,
#   'img': '/apps/dota2/images/heroes/crystal_maiden_full.png?',
#   'int_gain': 2.9,
#   'legs': 2,
#   'localized_name': 'Crystal Maiden',
#   'move_speed': 275,
#   'name': 'npc_dota_hero_crystal_maiden',
#   'primary_attr': 'int',
#   'pro_ban': 8,
#   'pro_pick': 9,
#   'pro_win': 1,
#   'projectile_speed': 900,
#   'roles': ['Support', 'Disabler', 'Nuker', 'Jungler'],
#   'str_gain': 2,
#   'turn_rate': 0.5},
#  {'1000_pick': 6751,
#   '1000_win': 3443,
#   '2000_pick': 12221,
#   '2000_win': 6444,
#   '3000_pick': 11805,
#   '3000_win': 6212,
#   '4000_pick': 3176,
#   '4000_win': 1705,
#   '5000_pick': 425,
#   '5000_win': 226,
#   'agi_gain': 1.9,
#   'attack_range': 625,
#   'attack_rate': 1.7,
#   'attack_type': 'Ranged',
#   'base_agi': 26,
#   'base_armor': -3,
#   'base_attack_max': 25,
#   'base_attack_min': 14,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 15,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 17,
#   'cm_enabled': True,
#   'hero_id': 6,
#   'icon': '/apps/dota2/images/heroes/drow_ranger_icon.png',
#   'id': 6,
#   'img': '/apps/dota2/images/heroes/drow_ranger_full.png?',
#   'int_gain': 1.4,
#   'legs': 2,
#   'localized_name': 'Drow Ranger',
#   'move_speed': 285,
#   'name': 'npc_dota_hero_drow_ranger',
#   'primary_attr': 'agi',
#   'pro_ban': 74,
#   'pro_pick': 31,
#   'pro_win': 19,
#   'projectile_speed': 1250,
#   'roles': ['Carry', 'Disabler', 'Pusher'],
#   'str_gain': 1.9,
#   'turn_rate': 0.7},
#  {'1000_pick': 9182,
#   '1000_win': 4653,
#   '2000_pick': 23976,
#   '2000_win': 11958,
#   '3000_pick': 34142,
#   '3000_win': 17161,
#   '4000_pick': 13477,
#   '4000_win': 6749,
#   '5000_pick': 2344,
#   '5000_win': 1143,
#   'agi_gain': 1.4,
#   'attack_range': 150,
#   'attack_rate': 1.7,
#   'attack_type': 'Melee',
#   'base_agi': 12,
#   'base_armor': 1,
#   'base_attack_max': 34,
#   'base_attack_min': 24,
#   'base_health': 200,
#   'base_health_regen': 2,
#   'base_int': 16,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 22,
#   'cm_enabled': True,
#   'hero_id': 7,
#   'icon': '/apps/dota2/images/heroes/earthshaker_icon.png',
#   'id': 7,
#   'img': '/apps/dota2/images/heroes/earthshaker_full.png?',
#   'int_gain': 1.8,
#   'legs': 2,
#   'localized_name': 'Earthshaker',
#   'move_speed': 310,
#   'name': 'npc_dota_hero_earthshaker',
#   'primary_attr': 'str',
#   'pro_ban': 99,
#   'pro_pick': 165,
#   'pro_win': 77,
#   'projectile_speed': 0,
#   'roles': ['Support', 'Initiator', 'Disabler', 'Nuker'],
#   'str_gain': 3.2,
#   'turn_rate': 0.9},
#  {'1000_pick': 9205,
#   '1000_win': 4478,
#   '2000_pick': 21682,
#   '2000_win': 10884,
#   '3000_pick': 26580,
#   '3000_win': 13490,
#   '4000_pick': 8963,
#   '4000_win': 4526,
#   '5000_pick': 1231,
#   '5000_win': 618,
#   'agi_gain': 2.4,
#   'attack_range': 150,
#   'attack_rate': 1.4,
#   'attack_type': 'Melee',
#   'base_agi': 26,
#   'base_armor': 0,
#   'base_attack_max': 26,
#   'base_attack_min': 22,
#   'base_health': 200,
#   'base_health_regen': 2,
#   'base_int': 14,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 20,
#   'cm_enabled': True,
#   'hero_id': 8,
#   'icon': '/apps/dota2/images/heroes/juggernaut_icon.png',
#   'id': 8,
#   'img': '/apps/dota2/images/heroes/juggernaut_full.png?',
#   'int_gain': 1.4,
#   'legs': 2,
#   'localized_name': 'Juggernaut',
#   'move_speed': 295,
#   'name': 'npc_dota_hero_juggernaut',
#   'primary_attr': 'agi',
#   'pro_ban': 59,
#   'pro_pick': 68,
#   'pro_win': 41,
#   'projectile_speed': 0,
#   'roles': ['Carry', 'Pusher', 'Escape'],
#   'str_gain': 2.2,
#   'turn_rate': 0.6},
#  {'1000_pick': 8354,
#   '1000_win': 4126,
#   '2000_pick': 26233,
#   '2000_win': 13018,
#   '3000_pick': 38772,
#   '3000_win': 18917,
#   '4000_pick': 14242,
#   '4000_win': 6942,
#   '5000_pick': 2205,
#   '5000_win': 1064,
#   'agi_gain': 3.2,
#   'attack_range': 630,
#   'attack_rate': 1.7,
#   'attack_type': 'Ranged',
#   'base_agi': 18,
#   'base_armor': -1,
#   'base_attack_max': 32,
#   'base_attack_min': 21,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 17,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 17,
#   'cm_enabled': True,
#   'hero_id': 9,
#   'icon': '/apps/dota2/images/heroes/mirana_icon.png',
#   'id': 9,
#   'img': '/apps/dota2/images/heroes/mirana_full.png?',
#   'int_gain': 1.65,
#   'legs': 2,
#   'localized_name': 'Mirana',
#   'move_speed': 295,
#   'name': 'npc_dota_hero_mirana',
#   'primary_attr': 'agi',
#   'pro_ban': 157,
#   'pro_pick': 199,
#   'pro_win': 90,
#   'projectile_speed': 900,
#   'roles': ['Carry', 'Support', 'Escape', 'Nuker', 'Disabler'],
#   'str_gain': 2.15,
#   'turn_rate': 0.5},
#  {'1000_pick': 2786,
#   '1000_win': 1255,
#   '2000_pick': 6848,
#   '2000_win': 2971,
#   '3000_pick': 8482,
#   '3000_win': 3706,
#   '4000_pick': 3017,
#   '4000_win': 1281,
#   '5000_pick': 478,
#   '5000_win': 221,
#   'agi_gain': 3.7,
#   'attack_range': 350,
#   'attack_rate': 1.5,
#   'attack_type': 'Ranged',
#   'base_agi': 24,
#   'base_armor': -2,
#   'base_attack_max': 18,
#   'base_attack_min': 9,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 13,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 19,
#   'cm_enabled': True,
#   'hero_id': 10,
#   'icon': '/apps/dota2/images/heroes/morphling_icon.png',
#   'id': 10,
#   'img': '/apps/dota2/images/heroes/morphling_full.png?',
#   'int_gain': 1.1,
#   'legs': 0,
#   'localized_name': 'Morphling',
#   'move_speed': 280,
#   'name': 'npc_dota_hero_morphling',
#   'primary_attr': 'agi',
#   'pro_ban': 8,
#   'pro_pick': 13,
#   'pro_win': 6,
#   'projectile_speed': 1300,
#   'roles': ['Carry', 'Escape', 'Durable', 'Nuker', 'Disabler'],
#   'str_gain': 2.3,
#   'turn_rate': 0.6},
#  {'1000_pick': 8352,
#   '1000_win': 4165,
#   '2000_pick': 21482,
#   '2000_win': 10282,
#   '3000_pick': 27179,
#   '3000_win': 12851,
#   '4000_pick': 8676,
#   '4000_win': 4037,
#   '5000_pick': 1177,
#   '5000_win': 549,
#   'agi_gain': 2.9,
#   'attack_range': 500,
#   'attack_rate': 1.7,
#   'attack_type': 'Ranged',
#   'base_agi': 20,
#   'base_armor': -2,
#   'base_attack_max': 21,
#   'base_attack_min': 15,
#   'base_health': 200,
#   'base_health_regen': 1.75,
#   'base_int': 18,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 15,
#   'cm_enabled': True,
#   'hero_id': 11,
#   'icon': '/apps/dota2/images/heroes/nevermore_icon.png',
#   'id': 11,
#   'img': '/apps/dota2/images/heroes/nevermore_full.png?',
#   'int_gain': 2,
#   'legs': 0,
#   'localized_name': 'Shadow Fiend',
#   'move_speed': 310,
#   'name': 'npc_dota_hero_nevermore',
#   'primary_attr': 'agi',
#   'pro_ban': 20,
#   'pro_pick': 42,
#   'pro_win': 16,
#   'projectile_speed': 1200,
#   'roles': ['Carry', 'Nuker'],
#   'str_gain': 2.3,
#   'turn_rate': 1},
#  {'1000_pick': 5708,
#   '1000_win': 2849,
#   '2000_pick': 10566,
#   '2000_win': 5328,
#   '3000_pick': 10650,
#   '3000_win': 5244,
#   '4000_pick': 3262,
#   '4000_win': 1630,
#   '5000_pick': 497,
#   '5000_win': 242,
#   'agi_gain': 2.8,
#   'attack_range': 150,
#   'attack_rate': 1.7,
#   'attack_type': 'Melee',
#   'base_agi': 29,
#   'base_armor': 0,
#   'base_attack_max': 44,
#   'base_attack_min': 22,
#   'base_health': 200,
#   'base_health_regen': 3,
#   'base_int': 21,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 21,
#   'cm_enabled': True,
#   'hero_id': 12,
#   'icon': '/apps/dota2/images/heroes/phantom_lancer_icon.png',
#   'id': 12,
#   'img': '/apps/dota2/images/heroes/phantom_lancer_full.png?',
#   'int_gain': 2,
#   'legs': 2,
#   'localized_name': 'Phantom Lancer',
#   'move_speed': 285,
#   'name': 'npc_dota_hero_phantom_lancer',
#   'primary_attr': 'agi',
#   'pro_ban': 104,
#   'pro_pick': 73,
#   'pro_win': 34,
#   'projectile_speed': 900,
#   'roles': ['Carry', 'Escape', 'Pusher', 'Nuker'],
#   'str_gain': 2,
#   'turn_rate': 0.6},
#  {'1000_pick': 2812,
#   '1000_win': 1152,
#   '2000_pick': 8141,
#   '2000_win': 3456,
#   '3000_pick': 12484,
#   '3000_win': 5413,
#   '4000_pick': 5181,
#   '4000_win': 2270,
#   '5000_pick': 1221,
#   '5000_win': 542,
#   'agi_gain': 1.7,
#   'attack_range': 550,
#   'attack_rate': 1.7,
#   'attack_type': 'Ranged',
#   'base_agi': 22,
#   'base_armor': -2,
#   'base_attack_max': 39,
#   'base_attack_min': 28,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 25,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 15,
#   'cm_enabled': True,
#   'hero_id': 13,
#   'icon': '/apps/dota2/images/heroes/puck_icon.png',
#   'id': 13,
#   'img': '/apps/dota2/images/heroes/puck_full.png?',
#   'int_gain': 2.4,
#   'legs': 2,
#   'localized_name': 'Puck',
#   'move_speed': 295,
#   'name': 'npc_dota_hero_puck',
#   'primary_attr': 'int',
#   'pro_ban': 269,
#   'pro_pick': 245,
#   'pro_win': 126,
#   'projectile_speed': 900,
#   'roles': ['Initiator', 'Disabler', 'Escape', 'Nuker'],
#   'str_gain': 2,
#   'turn_rate': 0.5},
#  {'1000_pick': 19717,
#   '1000_win': 10347,
#   '2000_pick': 50769,
#   '2000_win': 27138,
#   '3000_pick': 65211,
#   '3000_win': 35207,
#   '4000_pick': 22188,
#   '4000_win': 11875,
#   '5000_pick': 3060,
#   '5000_win': 1600,
#   'agi_gain': 1.5,
#   'attack_range': 150,
#   'attack_rate': 1.7,
#   'attack_type': 'Melee',
#   'base_agi': 14,
#   'base_armor': -1,
#   'base_attack_max': 33,
#   'base_attack_min': 27,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 14,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 25,
#   'cm_enabled': True,
#   'hero_id': 14,
#   'icon': '/apps/dota2/images/heroes/pudge_icon.png',
#   'id': 14,
#   'img': '/apps/dota2/images/heroes/pudge_full.png?',
#   'int_gain': 1.5,
#   'legs': 2,
#   'localized_name': 'Pudge',
#   'move_speed': 280,
#   'name': 'npc_dota_hero_pudge',
#   'primary_attr': 'str',
#   'pro_ban': 9,
#   'pro_pick': 19,
#   'pro_win': 11,
#   'projectile_speed': 0,
#   'roles': ['Disabler', 'Initiator', 'Durable', 'Nuker'],
#   'str_gain': 3.5,
#   'turn_rate': 0.7},
#  {'1000_pick': 2463,
#   '1000_win': 1180,
#   '2000_pick': 4771,
#   '2000_win': 2213,
#   '3000_pick': 5868,
#   '3000_win': 2731,
#   '4000_pick': 1958,
#   '4000_win': 938,
#   '5000_pick': 364,
#   '5000_win': 170,
#   'agi_gain': 1.8,
#   'attack_range': 475,
#   'attack_rate': 1.7,
#   'attack_type': 'Ranged',
#   'base_agi': 22,
#   'base_armor': -1,
#   'base_attack_max': 25,
#   'base_attack_min': 23,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 21,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 21,
#   'cm_enabled': True,
#   'hero_id': 15,
#   'icon': '/apps/dota2/images/heroes/razor_icon.png',
#   'id': 15,
#   'img': '/apps/dota2/images/heroes/razor_full.png?',
#   'int_gain': 1.8,
#   'legs': 0,
#   'localized_name': 'Razor',
#   'move_speed': 285,
#   'name': 'npc_dota_hero_razor',
#   'primary_attr': 'agi',
#   'pro_ban': 88,
#   'pro_pick': 84,
#   'pro_win': 37,
#   'projectile_speed': 2000,
#   'roles': ['Carry', 'Durable', 'Nuker', 'Pusher'],
#   'str_gain': 2.6,
#   'turn_rate': 0.5},
#  {'1000_pick': 4731,
#   '1000_win': 2334,
#   '2000_pick': 12442,
#   '2000_win': 6083,
#   '3000_pick': 15194,
#   '3000_win': 7272,
#   '4000_pick': 5244,
#   '4000_win': 2579,
#   '5000_pick': 932,
#   '5000_win': 449,
#   'agi_gain': 2.1,
#   'attack_range': 150,
#   'attack_rate': 1.7,
#   'attack_type': 'Melee',
#   'base_agi': 19,
#   'base_armor': 0,
#   'base_attack_max': 41,
#   'base_attack_min': 25,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 16,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 22,
#   'cm_enabled': True,
#   'hero_id': 16,
#   'icon': '/apps/dota2/images/heroes/sand_king_icon.png',
#   'id': 16,
#   'img': '/apps/dota2/images/heroes/sand_king_full.png?',
#   'int_gain': 1.8,
#   'legs': 6,
#   'localized_name': 'Sand King',
#   'move_speed': 295,
#   'name': 'npc_dota_hero_sand_king',
#   'primary_attr': 'str',
#   'pro_ban': 68,
#   'pro_pick': 206,
#   'pro_win': 93,
#   'projectile_speed': 900,
#   'roles': ['Initiator', 'Disabler', 'Nuker', 'Escape', 'Jungler'],
#   'str_gain': 2.9,
#   'turn_rate': 0.5},
#  {'1000_pick': 6599,
#   '1000_win': 3292,
#   '2000_pick': 17208,
#   '2000_win': 8760,
#   '3000_pick': 23476,
#   '3000_win': 12137,
#   '4000_pick': 8482,
#   '4000_win': 4340,
#   '5000_pick': 1382,
#   '5000_win': 739,
#   'agi_gain': 1.5,
#   'attack_range': 480,
#   'attack_rate': 1.7,
#   'attack_type': 'Ranged',
#   'base_agi': 22,
#   'base_armor': 2,
#   'base_attack_max': 32,
#   'base_attack_min': 22,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 24,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 19,
#   'cm_enabled': True,
#   'hero_id': 17,
#   'icon': '/apps/dota2/images/heroes/storm_spirit_icon.png',
#   'id': 17,
#   'img': '/apps/dota2/images/heroes/storm_spirit_full.png?',
#   'int_gain': 3,
#   'legs': 2,
#   'localized_name': 'Storm Spirit',
#   'move_speed': 285,
#   'name': 'npc_dota_hero_storm_spirit',
#   'primary_attr': 'int',
#   'pro_ban': 107,
#   'pro_pick': 92,
#   'pro_win': 48,
#   'projectile_speed': 1100,
#   'roles': ['Carry', 'Escape', 'Nuker', 'Initiator', 'Disabler'],
#   'str_gain': 1.8,
#   'turn_rate': 0.8},
#  {'1000_pick': 8985,
#   '1000_win': 4746,
#   '2000_pick': 18756,
#   '2000_win': 10004,
#   '3000_pick': 20770,
#   '3000_win': 10858,
#   '4000_pick': 6534,
#   '4000_win': 3357,
#   '5000_pick': 972,
#   '5000_win': 485,
#   'agi_gain': 2,
#   'attack_range': 150,
#   'attack_rate': 1.8,
#   'attack_type': 'Melee',
#   'base_agi': 21,
#   'base_armor': 2,
#   'base_attack_max': 43,
#   'base_attack_min': 41,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 16,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 23,
#   'cm_enabled': True,
#   'hero_id': 18,
#   'icon': '/apps/dota2/images/heroes/sven_icon.png',
#   'id': 18,
#   'img': '/apps/dota2/images/heroes/sven_full.png?',
#   'int_gain': 1.3,
#   'legs': 2,
#   'localized_name': 'Sven',
#   'move_speed': 290,
#   'name': 'npc_dota_hero_sven',
#   'primary_attr': 'str',
#   'pro_ban': 102,
#   'pro_pick': 66,
#   'pro_win': 31,
#   'projectile_speed': 0,
#   'roles': ['Carry', 'Disabler', 'Initiator', 'Durable', 'Nuker'],
#   'str_gain': 3,
#   'turn_rate': 0.6},
#  {'1000_pick': 5017,
#   '1000_win': 2185,
#   '2000_pick': 10737,
#   '2000_win': 4752,
#   '3000_pick': 12580,
#   '3000_win': 5648,
#   '4000_pick': 4610,
#   '4000_win': 2183,
#   '5000_pick': 1036,
#   '5000_win': 516,
#   'agi_gain': 0,
#   'attack_range': 150,
#   'attack_rate': 1.7,
#   'attack_type': 'Melee',
#   'base_agi': 0,
#   'base_armor': 0,
#   'base_attack_max': 50,
#   'base_attack_min': 44,
#   'base_health': 200,
#   'base_health_regen': 2.5,
#   'base_int': 17,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 30,
#   'cm_enabled': True,
#   'hero_id': 19,
#   'icon': '/apps/dota2/images/heroes/tiny_icon.png',
#   'id': 19,
#   'img': '/apps/dota2/images/heroes/tiny_full.png?',
#   'int_gain': 1.6,
#   'legs': 2,
#   'localized_name': 'Tiny',
#   'move_speed': 285,
#   'name': 'npc_dota_hero_tiny',
#   'primary_attr': 'str',
#   'pro_ban': 95,
#   'pro_pick': 96,
#   'pro_win': 50,
#   'projectile_speed': 900,
#   'roles': ['Carry', 'Nuker', 'Pusher', 'Initiator', 'Durable', 'Disabler'],
#   'str_gain': 3.3,
#   'turn_rate': 0.5},
#  {'1000_pick': 4229,
#   '1000_win': 2292,
#   '2000_pick': 10526,
#   '2000_win': 5735,
#   '3000_pick': 13922,
#   '3000_win': 7610,
#   '4000_pick': 4684,
#   '4000_win': 2580,
#   '5000_pick': 720,
#   '5000_win': 378,
#   'agi_gain': 3.3,
#   'attack_range': 400,
#   'attack_rate': 1.7,
#   'attack_type': 'Ranged',
#   'base_agi': 27,
#   'base_armor': 0,
#   'base_attack_max': 20,
#   'base_attack_min': 12,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 13,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 18,
#   'cm_enabled': True,
#   'hero_id': 20,
#   'icon': '/apps/dota2/images/heroes/vengefulspirit_icon.png',
#   'id': 20,
#   'img': '/apps/dota2/images/heroes/vengefulspirit_full.png?',
#   'int_gain': 1.5,
#   'legs': 2,
#   'localized_name': 'Vengeful Spirit',
#   'move_speed': 295,
#   'name': 'npc_dota_hero_vengefulspirit',
#   'primary_attr': 'agi',
#   'pro_ban': 153,
#   'pro_pick': 167,
#   'pro_win': 88,
#   'projectile_speed': 1500,
#   'roles': ['Support', 'Initiator', 'Disabler', 'Nuker', 'Escape'],
#   'str_gain': 2.9,
#   'turn_rate': 0.6},
#  {'1000_pick': 9334,
#   '1000_win': 4514,
#   '2000_pick': 20105,
#   '2000_win': 9538,
#   '3000_pick': 23049,
#   '3000_win': 10923,
#   '4000_pick': 7086,
#   '4000_win': 3352,
#   '5000_pick': 909,
#   '5000_win': 439,
#   'agi_gain': 1.4,
#   'attack_range': 600,
#   'attack_rate': 1.5,
#   'attack_type': 'Ranged',
#   'base_agi': 17,
#   'base_armor': -1,
#   'base_attack_max': 34,
#   'base_attack_min': 22,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 22,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 15,
#   'cm_enabled': True,
#   'hero_id': 21,
#   'icon': '/apps/dota2/images/heroes/windrunner_icon.png',
#   'id': 21,
#   'img': '/apps/dota2/images/heroes/windrunner_full.png?',
#   'int_gain': 2.6,
#   'legs': 2,
#   'localized_name': 'Windranger',
#   'move_speed': 295,
#   'name': 'npc_dota_hero_windrunner',
#   'primary_attr': 'int',
#   'pro_ban': 3,
#   'pro_pick': 16,
#   'pro_win': 7,
#   'projectile_speed': 1250,
#   'roles': ['Carry', 'Support', 'Disabler', 'Escape', 'Nuker'],
#   'str_gain': 2.8,
#   'turn_rate': 0.8},
#  {'1000_pick': 6326,
#   '1000_win': 3679,
#   '2000_pick': 14562,
#   '2000_win': 8423,
#   '3000_pick': 18543,
#   '3000_win': 10645,
#   '4000_pick': 6786,
#   '4000_win': 3777,
#   '5000_pick': 920,
#   '5000_win': 476,
#   'agi_gain': 1.2,
#   'attack_range': 350,
#   'attack_rate': 1.7,
#   'attack_type': 'Ranged',
#   'base_agi': 11,
#   'base_armor': 0,
#   'base_attack_max': 29,
#   'base_attack_min': 21,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 22,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 19,
#   'cm_enabled': True,
#   'hero_id': 22,
#   'icon': '/apps/dota2/images/heroes/zuus_icon.png',
#   'id': 22,
#   'img': '/apps/dota2/images/heroes/zuus_full.png?',
#   'int_gain': 2.7,
#   'legs': 2,
#   'localized_name': 'Zeus',
#   'move_speed': 300,
#   'name': 'npc_dota_hero_zuus',
#   'primary_attr': 'int',
#   'pro_ban': 18,
#   'pro_pick': 31,
#   'pro_win': 15,
#   'projectile_speed': 1100,
#   'roles': ['Nuker'],
#   'str_gain': 2.6,
#   'turn_rate': 0.6},
#  {'1000_pick': 5264,
#   '1000_win': 2552,
#   '2000_pick': 13071,
#   '2000_win': 6395,
#   '3000_pick': 17842,
#   '3000_win': 8843,
#   '4000_pick': 6106,
#   '4000_win': 3084,
#   '5000_pick': 853,
#   '5000_win': 414,
#   'agi_gain': 1.3,
#   'attack_range': 150,
#   'attack_rate': 1.7,
#   'attack_type': 'Melee',
#   'base_agi': 14,
#   'base_armor': 2,
#   'base_attack_max': 36,
#   'base_attack_min': 26,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 18,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 24,
#   'cm_enabled': True,
#   'hero_id': 23,
#   'icon': '/apps/dota2/images/heroes/kunkka_icon.png',
#   'id': 23,
#   'img': '/apps/dota2/images/heroes/kunkka_full.png?',
#   'int_gain': 1.5,
#   'legs': 2,
#   'localized_name': 'Kunkka',
#   'move_speed': 300,
#   'name': 'npc_dota_hero_kunkka',
#   'primary_attr': 'str',
#   'pro_ban': 15,
#   'pro_pick': 61,
#   'pro_win': 35,
#   'projectile_speed': 900,
#   'roles': ['Carry', 'Disabler', 'Initiator', 'Durable', 'Nuker'],
#   'str_gain': 3.3,
#   'turn_rate': 0.6},
#  {'1000_pick': 5333,
#   '1000_win': 2457,
#   '2000_pick': 11634,
#   '2000_win': 5199,
#   '3000_pick': 13621,
#   '3000_win': 6149,
#   '4000_pick': 4155,
#   '4000_win': 1936,
#   '5000_pick': 594,
#   '5000_win': 276,
#   'agi_gain': 1.5,
#   'attack_range': 670,
#   'attack_rate': 1.6,
#   'attack_type': 'Ranged',
#   'base_agi': 16,
#   'base_armor': -1,
#   'base_attack_max': 31,
#   'base_attack_min': 13,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 27,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 18,
#   'cm_enabled': True,
#   'hero_id': 25,
#   'icon': '/apps/dota2/images/heroes/lina_icon.png',
#   'id': 25,
#   'img': '/apps/dota2/images/heroes/lina_full.png?',
#   'int_gain': 3.2,
#   'legs': 2,
#   'localized_name': 'Lina',
#   'move_speed': 295,
#   'name': 'npc_dota_hero_lina',
#   'primary_attr': 'int',
#   'pro_ban': 11,
#   'pro_pick': 22,
#   'pro_win': 13,
#   'projectile_speed': 1000,
#   'roles': ['Support', 'Carry', 'Nuker', 'Disabler'],
#   'str_gain': 1.8,
#   'turn_rate': 0.5},
#  {'1000_pick': 5920,
#   '1000_win': 2795,
#   '2000_pick': 15541,
#   '2000_win': 7330,
#   '3000_pick': 21149,
#   '3000_win': 10222,
#   '4000_pick': 7234,
#   '4000_win': 3495,
#   '5000_pick': 1048,
#   '5000_win': 495,
#   'agi_gain': 1.5,
#   'attack_range': 600,
#   'attack_rate': 1.7,
#   'attack_type': 'Ranged',
#   'base_agi': 15,
#   'base_armor': -1,
#   'base_attack_max': 33,
#   'base_attack_min': 27,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 20,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 16,
#   'cm_enabled': True,
#   'hero_id': 26,
#   'icon': '/apps/dota2/images/heroes/lion_icon.png',
#   'id': 26,
#   'img': '/apps/dota2/images/heroes/lion_full.png?',
#   'int_gain': 3,
#   'legs': 2,
#   'localized_name': 'Lion',
#   'move_speed': 290,
#   'name': 'npc_dota_hero_lion',
#   'primary_attr': 'int',
#   'pro_ban': 9,
#   'pro_pick': 53,
#   'pro_win': 30,
#   'projectile_speed': 900,
#   'roles': ['Support', 'Disabler', 'Nuker', 'Initiator'],
#   'str_gain': 2,
#   'turn_rate': 0.5},
#  {'1000_pick': 7294,
#   '1000_win': 3925,
#   '2000_pick': 15135,
#   '2000_win': 8076,
#   '3000_pick': 19113,
#   '3000_win': 10295,
#   '4000_pick': 7644,
#   '4000_win': 4092,
#   '5000_pick': 1571,
#   '5000_win': 835,
#   'agi_gain': 1.6,
#   'attack_range': 400,
#   'attack_rate': 1.7,
#   'attack_type': 'Ranged',
#   'base_agi': 16,
#   'base_armor': 0,
#   'base_attack_max': 57,
#   'base_attack_min': 50,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 21,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 21,
#   'cm_enabled': True,
#   'hero_id': 27,
#   'icon': '/apps/dota2/images/heroes/shadow_shaman_icon.png',
#   'id': 27,
#   'img': '/apps/dota2/images/heroes/shadow_shaman_full.png?',
#   'int_gain': 3,
#   'legs': 2,
#   'localized_name': 'Shadow Shaman',
#   'move_speed': 285,
#   'name': 'npc_dota_hero_shadow_shaman',
#   'primary_attr': 'int',
#   'pro_ban': 35,
#   'pro_pick': 80,
#   'pro_win': 40,
#   'projectile_speed': 900,
#   'roles': ['Support', 'Pusher', 'Disabler', 'Nuker', 'Initiator'],
#   'str_gain': 2.1,
#   'turn_rate': 0.5},
#  {'1000_pick': 4818,
#   '1000_win': 2386,
#   '2000_pick': 12225,
#   '2000_win': 6072,
#   '3000_pick': 15175,
#   '3000_win': 7687,
#   '4000_pick': 5005,
#   '4000_win': 2547,
#   '5000_pick': 726,
#   '5000_win': 389,
#   'agi_gain': 2.4,
#   'attack_range': 150,
#   'attack_rate': 1.7,
#   'attack_type': 'Melee',
#   'base_agi': 17,
#   'base_armor': 3,
#   'base_attack_max': 38,
#   'base_attack_min': 30,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 15,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 21,
#   'cm_enabled': True,
#   'hero_id': 28,
#   'icon': '/apps/dota2/images/heroes/slardar_icon.png',
#   'id': 28,
#   'img': '/apps/dota2/images/heroes/slardar_full.png?',
#   'int_gain': 1.5,
#   'legs': 0,
#   'localized_name': 'Slardar',
#   'move_speed': 290,
#   'name': 'npc_dota_hero_slardar',
#   'primary_attr': 'str',
#   'pro_ban': 39,
#   'pro_pick': 136,
#   'pro_win': 63,
#   'projectile_speed': 0,
#   'roles': ['Carry', 'Durable', 'Initiator', 'Disabler', 'Escape'],
#   'str_gain': 3.1,
#   'turn_rate': 0.5},
#  {'1000_pick': 3162,
#   '1000_win': 1655,
#   '2000_pick': 8242,
#   '2000_win': 4275,
#   '3000_pick': 10153,
#   '3000_win': 5320,
#   '4000_pick': 3316,
#   '4000_win': 1751,
#   '5000_pick': 415,
#   '5000_win': 230,
#   'agi_gain': 1.5,
#   'attack_range': 150,
#   'attack_rate': 1.7,
#   'attack_type': 'Melee',
#   'base_agi': 15,
#   'base_armor': 1,
#   'base_attack_max': 31,
#   'base_attack_min': 25,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 16,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 22,
#   'cm_enabled': True,
#   'hero_id': 29,
#   'icon': '/apps/dota2/images/heroes/tidehunter_icon.png',
#   'id': 29,
#   'img': '/apps/dota2/images/heroes/tidehunter_full.png?',
#   'int_gain': 1.7,
#   'legs': 2,
#   'localized_name': 'Tidehunter',
#   'move_speed': 305,
#   'name': 'npc_dota_hero_tidehunter',
#   'primary_attr': 'str',
#   'pro_ban': 59,
#   'pro_pick': 77,
#   'pro_win': 41,
#   'projectile_speed': 900,
#   'roles': ['Initiator', 'Durable', 'Disabler', 'Nuker'],
#   'str_gain': 3.3,
#   'turn_rate': 0.5},
#  {'1000_pick': 4230,
#   '1000_win': 2112,
#   '2000_pick': 9787,
#   '2000_win': 5021,
#   '3000_pick': 11606,
#   '3000_win': 5900,
#   '4000_pick': 3781,
#   '4000_win': 1898,
#   '5000_pick': 551,
#   '5000_win': 288,
#   'agi_gain': 1.4,
#   'attack_range': 600,
#   'attack_rate': 1.7,
#   'attack_type': 'Ranged',
#   'base_agi': 13,
#   'base_armor': -1,
#   'base_attack_max': 37,
#   'base_attack_min': 27,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 24,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 16,
#   'cm_enabled': True,
#   'hero_id': 30,
#   'icon': '/apps/dota2/images/heroes/witch_doctor_icon.png',
#   'id': 30,
#   'img': '/apps/dota2/images/heroes/witch_doctor_full.png?',
#   'int_gain': 2.9,
#   'legs': 2,
#   'localized_name': 'Witch Doctor',
#   'move_speed': 305,
#   'name': 'npc_dota_hero_witch_doctor',
#   'primary_attr': 'int',
#   'pro_ban': 20,
#   'pro_pick': 99,
#   'pro_win': 52,
#   'projectile_speed': 1200,
#   'roles': ['Support', 'Nuker', 'Disabler'],
#   'str_gain': 2.1,
#   'turn_rate': 0.5},
#  {'1000_pick': 3906,
#   '1000_win': 2079,
#   '2000_pick': 9269,
#   '2000_win': 4959,
#   '3000_pick': 13188,
#   '3000_win': 7220,
#   '4000_pick': 5644,
#   '4000_win': 3042,
#   '5000_pick': 1209,
#   '5000_win': 630,
#   'agi_gain': 2,
#   'attack_range': 550,
#   'attack_rate': 1.7,
#   'attack_type': 'Ranged',
#   'base_agi': 15,
#   'base_armor': -1,
#   'base_attack_max': 33,
#   'base_attack_min': 24,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 18,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 18,
#   'cm_enabled': True,
#   'hero_id': 31,
#   'icon': '/apps/dota2/images/heroes/lich_icon.png',
#   'id': 31,
#   'img': '/apps/dota2/images/heroes/lich_full.png?',
#   'int_gain': 3.25,
#   'legs': 2,
#   'localized_name': 'Lich',
#   'move_speed': 315,
#   'name': 'npc_dota_hero_lich',
#   'primary_attr': 'int',
#   'pro_ban': 236,
#   'pro_pick': 84,
#   'pro_win': 45,
#   'projectile_speed': 900,
#   'roles': ['Support', 'Nuker'],
#   'str_gain': 1.85,
#   'turn_rate': 0.5},
#  {'1000_pick': 9629,
#   '1000_win': 5139,
#   '2000_pick': 18741,
#   '2000_win': 9878,
#   '3000_pick': 20545,
#   '3000_win': 10719,
#   '4000_pick': 6646,
#   '4000_win': 3365,
#   '5000_pick': 934,
#   '5000_win': 432,
#   'agi_gain': 2.2,
#   'attack_range': 150,
#   'attack_rate': 1.7,
#   'attack_type': 'Melee',
#   'base_agi': 30,
#   'base_armor': 0,
#   'base_attack_max': 8,
#   'base_attack_min': 4,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 14,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 17,
#   'cm_enabled': True,
#   'hero_id': 32,
#   'icon': '/apps/dota2/images/heroes/riki_icon.png',
#   'id': 32,
#   'img': '/apps/dota2/images/heroes/riki_full.png?',
#   'int_gain': 1.3,
#   'legs': 2,
#   'localized_name': 'Riki',
#   'move_speed': 275,
#   'name': 'npc_dota_hero_riki',
#   'primary_attr': 'agi',
#   'pro_ban': 17,
#   'pro_pick': 11,
#   'pro_win': 4,
#   'projectile_speed': 900,
#   'roles': ['Carry', 'Escape', 'Disabler'],
#   'str_gain': 1.9,
#   'turn_rate': 0.6},
#  {'1000_pick': 2847,
#   '1000_win': 1452,
#   '2000_pick': 7255,
#   '2000_win': 3682,
#   '3000_pick': 8380,
#   '3000_win': 4062,
#   '4000_pick': 2390,
#   '4000_win': 1197,
#   '5000_pick': 319,
#   '5000_win': 160,
#   'agi_gain': 1,
#   'attack_range': 500,
#   'attack_rate': 1.7,
#   'attack_type': 'Ranged',
#   'base_agi': 14,
#   'base_armor': 2,
#   'base_attack_max': 28,
#   'base_attack_min': 22,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 20,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 17,
#   'cm_enabled': True,
#   'hero_id': 33,
#   'icon': '/apps/dota2/images/heroes/enigma_icon.png',
#   'id': 33,
#   'img': '/apps/dota2/images/heroes/enigma_full.png?',
#   'int_gain': 3.4,
#   'legs': 0,
#   'localized_name': 'Enigma',
#   'move_speed': 300,
#   'name': 'npc_dota_hero_enigma',
#   'primary_attr': 'int',
#   'pro_ban': 9,
#   'pro_pick': 10,
#   'pro_win': 5,
#   'projectile_speed': 900,
#   'roles': ['Disabler', 'Jungler', 'Initiator', 'Pusher'],
#   'str_gain': 2.4,
#   'turn_rate': 0.5},
#  {'1000_pick': 5766,
#   '1000_win': 2763,
#   '2000_pick': 15270,
#   '2000_win': 7602,
#   '3000_pick': 20107,
#   '3000_win': 10392,
#   '4000_pick': 6824,
#   '4000_win': 3555,
#   '5000_pick': 1125,
#   '5000_win': 615,
#   'agi_gain': 1.2,
#   'attack_range': 500,
#   'attack_rate': 1.7,
#   'attack_type': 'Ranged',
#   'base_agi': 13,
#   'base_armor': 2,
#   'base_attack_max': 28,
#   'base_attack_min': 22,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 30,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 17,
#   'cm_enabled': True,
#   'hero_id': 34,
#   'icon': '/apps/dota2/images/heroes/tinker_icon.png',
#   'id': 34,
#   'img': '/apps/dota2/images/heroes/tinker_full.png?',
#   'int_gain': 2.2,
#   'legs': 2,
#   'localized_name': 'Tinker',
#   'move_speed': 305,
#   'name': 'npc_dota_hero_tinker',
#   'primary_attr': 'int',
#   'pro_ban': 89,
#   'pro_pick': 64,
#   'pro_win': 30,
#   'projectile_speed': 900,
#   'roles': ['Carry', 'Nuker', 'Pusher'],
#   'str_gain': 2.3,
#   'turn_rate': 0.6},
#  {'1000_pick': 17648,
#   '1000_win': 8915,
#   '2000_pick': 34428,
#   '2000_win': 17782,
#   '3000_pick': 32622,
#   '3000_win': 16761,
#   '4000_pick': 7846,
#   '4000_win': 4083,
#   '5000_pick': 799,
#   '5000_win': 409,
#   'agi_gain': 2.7,
#   'attack_range': 550,
#   'attack_rate': 1.7,
#   'attack_type': 'Ranged',
#   'base_agi': 21,
#   'base_armor': -1,
#   'base_attack_max': 21,
#   'base_attack_min': 15,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 15,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 16,
#   'cm_enabled': True,
#   'hero_id': 35,
#   'icon': '/apps/dota2/images/heroes/sniper_icon.png',
#   'id': 35,
#   'img': '/apps/dota2/images/heroes/sniper_full.png?',
#   'int_gain': 2.6,
#   'legs': 2,
#   'localized_name': 'Sniper',
#   'move_speed': 285,
#   'name': 'npc_dota_hero_sniper',
#   'primary_attr': 'agi',
#   'pro_ban': 68,
#   'pro_pick': 58,
#   'pro_win': 25,
#   'projectile_speed': 3000,
#   'roles': ['Carry', 'Nuker'],
#   'str_gain': 1.7,
#   'turn_rate': 0.7},
#  {'1000_pick': 11631,
#   '1000_win': 6342,
#   '2000_pick': 26977,
#   '2000_win': 14565,
#   '3000_pick': 31348,
#   '3000_win': 16952,
#   '4000_pick': 9342,
#   '4000_win': 4976,
#   '5000_pick': 1317,
#   '5000_win': 688,
#   'agi_gain': 1.2,
#   'attack_range': 550,
#   'attack_rate': 1.7,
#   'attack_type': 'Ranged',
#   'base_agi': 15,
#   'base_armor': 1,
#   'base_attack_max': 26,
#   'base_attack_min': 22,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 22,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 16,
#   'cm_enabled': True,
#   'hero_id': 36,
#   'icon': '/apps/dota2/images/heroes/necrolyte_icon.png',
#   'id': 36,
#   'img': '/apps/dota2/images/heroes/necrolyte_full.png?',
#   'int_gain': 2.5,
#   'legs': 2,
#   'localized_name': 'Necrophos',
#   'move_speed': 285,
#   'name': 'npc_dota_hero_necrolyte',
#   'primary_attr': 'int',
#   'pro_ban': 114,
#   'pro_pick': 71,
#   'pro_win': 34,
#   'projectile_speed': 900,
#   'roles': ['Carry', 'Nuker', 'Durable', 'Disabler'],
#   'str_gain': 2.3,
#   'turn_rate': 0.5},
#  {'1000_pick': 2428,
#   '1000_win': 1270,
#   '2000_pick': 5549,
#   '2000_win': 2834,
#   '3000_pick': 6762,
#   '3000_win': 3546,
#   '4000_pick': 2088,
#   '4000_win': 1038,
#   '5000_pick': 299,
#   '5000_win': 145,
#   'agi_gain': 1,
#   'attack_range': 600,
#   'attack_rate': 1.7,
#   'attack_type': 'Ranged',
#   'base_agi': 10,
#   'base_armor': 1,
#   'base_attack_max': 32,
#   'base_attack_min': 22,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 24,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 22,
#   'cm_enabled': True,
#   'hero_id': 37,
#   'icon': '/apps/dota2/images/heroes/warlock_icon.png',
#   'id': 37,
#   'img': '/apps/dota2/images/heroes/warlock_full.png?',
#   'int_gain': 2.7,
#   'legs': 2,
#   'localized_name': 'Warlock',
#   'move_speed': 295,
#   'name': 'npc_dota_hero_warlock',
#   'primary_attr': 'int',
#   'pro_ban': 2,
#   'pro_pick': 19,
#   'pro_win': 7,
#   'projectile_speed': 1200,
#   'roles': ['Support', 'Initiator', 'Disabler'],
#   'str_gain': 2.8,
#   'turn_rate': 0.5},
#  {'1000_pick': 1156,
#   '1000_win': 542,
#   '2000_pick': 2830,
#   '2000_win': 1376,
#   '3000_pick': 3791,
#   '3000_win': 1811,
#   '4000_pick': 1531,
#   '4000_win': 733,
#   '5000_pick': 436,
#   '5000_win': 229,
#   'agi_gain': 1.6,
#   'attack_range': 150,
#   'attack_rate': 1.7,
#   'attack_type': 'Melee',
#   'base_agi': 18,
#   'base_armor': 2,
#   'base_attack_max': 45,
#   'base_attack_min': 41,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 16,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 23,
#   'cm_enabled': True,
#   'hero_id': 38,
#   'icon': '/apps/dota2/images/heroes/beastmaster_icon.png',
#   'id': 38,
#   'img': '/apps/dota2/images/heroes/beastmaster_full.png?',
#   'int_gain': 1.9,
#   'legs': 2,
#   'localized_name': 'Beastmaster',
#   'move_speed': 310,
#   'name': 'npc_dota_hero_beastmaster',
#   'primary_attr': 'str',
#   'pro_ban': 309,
#   'pro_pick': 120,
#   'pro_win': 58,
#   'projectile_speed': 0,
#   'roles': ['Initiator', 'Disabler', 'Durable', 'Nuker'],
#   'str_gain': 2.5,
#   'turn_rate': 0.5},
#  {'1000_pick': 3958,
#   '1000_win': 1774,
#   '2000_pick': 10564,
#   '2000_win': 4780,
#   '3000_pick': 14730,
#   '3000_win': 6748,
#   '4000_pick': 5937,
#   '4000_win': 2811,
#   '5000_pick': 1259,
#   '5000_win': 621,
#   'agi_gain': 2,
#   'attack_range': 550,
#   'attack_rate': 1.5,
#   'attack_type': 'Ranged',
#   'base_agi': 18,
#   'base_armor': -1,
#   'base_attack_max': 29,
#   'base_attack_min': 21,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 24,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 16,
#   'cm_enabled': True,
#   'hero_id': 39,
#   'icon': '/apps/dota2/images/heroes/queenofpain_icon.png',
#   'id': 39,
#   'img': '/apps/dota2/images/heroes/queenofpain_full.png?',
#   'int_gain': 2.5,
#   'legs': 2,
#   'localized_name': 'Queen of Pain',
#   'move_speed': 295,
#   'name': 'npc_dota_hero_queenofpain',
#   'primary_attr': 'int',
#   'pro_ban': 185,
#   'pro_pick': 218,
#   'pro_win': 111,
#   'projectile_speed': 1500,
#   'roles': ['Carry', 'Nuker', 'Escape'],
#   'str_gain': 2,
#   'turn_rate': 0.5},
#  {'1000_pick': 6534,
#   '1000_win': 3408,
#   '2000_pick': 16851,
#   '2000_win': 8553,
#   '3000_pick': 22178,
#   '3000_win': 11118,
#   '4000_pick': 7998,
#   '4000_win': 4017,
#   '5000_pick': 1296,
#   '5000_win': 675,
#   'agi_gain': 2.8,
#   'attack_range': 450,
#   'attack_rate': 1.7,
#   'attack_type': 'Ranged',
#   'base_agi': 22,
#   'base_armor': 0,
#   'base_attack_max': 18,
#   'base_attack_min': 16,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 17,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 18,
#   'cm_enabled': True,
#   'hero_id': 40,
#   'icon': '/apps/dota2/images/heroes/venomancer_icon.png',
#   'id': 40,
#   'img': '/apps/dota2/images/heroes/venomancer_full.png?',
#   'int_gain': 1.8,
#   'legs': 0,
#   'localized_name': 'Venomancer',
#   'move_speed': 275,
#   'name': 'npc_dota_hero_venomancer',
#   'primary_attr': 'agi',
#   'pro_ban': 185,
#   'pro_pick': 94,
#   'pro_win': 46,
#   'projectile_speed': 900,
#   'roles': ['Support', 'Nuker', 'Initiator', 'Pusher', 'Disabler'],
#   'str_gain': 1.9,
#   'turn_rate': 0.5},
#  {'1000_pick': 8224,
#   '1000_win': 4025,
#   '2000_pick': 19343,
#   '2000_win': 9605,
#   '3000_pick': 22820,
#   '3000_win': 11532,
#   '4000_pick': 7612,
#   '4000_win': 3862,
#   '5000_pick': 1108,
#   '5000_win': 559,
#   'agi_gain': 2.8,
#   'attack_range': 150,
#   'attack_rate': 1.7,
#   'attack_type': 'Melee',
#   'base_agi': 23,
#   'base_armor': 0,
#   'base_attack_max': 39,
#   'base_attack_min': 33,
#   'base_health': 200,
#   'base_health_regen': 2,
#   'base_int': 15,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 23,
#   'cm_enabled': True,
#   'hero_id': 41,
#   'icon': '/apps/dota2/images/heroes/faceless_void_icon.png',
#   'id': 41,
#   'img': '/apps/dota2/images/heroes/faceless_void_full.png?',
#   'int_gain': 1.5,
#   'legs': 2,
#   'localized_name': 'Faceless Void',
#   'move_speed': 295,
#   'name': 'npc_dota_hero_faceless_void',
#   'primary_attr': 'agi',
#   'pro_ban': 74,
#   'pro_pick': 67,
#   'pro_win': 27,
#   'projectile_speed': 900,
#   'roles': ['Carry', 'Initiator', 'Disabler', 'Escape', 'Durable'],
#   'str_gain': 2.1,
#   'turn_rate': 1},
#  {'1000_pick': 7959,
#   '1000_win': 4431,
#   '2000_pick': 15178,
#   '2000_win': 8284,
#   '3000_pick': 14825,
#   '3000_win': 8026,
#   '4000_pick': 3988,
#   '4000_win': 2089,
#   '5000_pick': 493,
#   '5000_win': 246,
#   'agi_gain': 1.7,
#   'attack_range': 150,
#   'attack_rate': 1.7,
#   'attack_type': 'Melee',
#   'base_agi': 18,
#   'base_armor': 0,
#   'base_attack_max': 41,
#   'base_attack_min': 39,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 18,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 22,
#   'cm_enabled': True,
#   'hero_id': 42,
#   'icon': '/apps/dota2/images/heroes/skeleton_king_icon.png',
#   'id': 42,
#   'img': '/apps/dota2/images/heroes/skeleton_king_full.png?',
#   'int_gain': 1.6,
#   'legs': 2,
#   'localized_name': 'Wraith King',
#   'move_speed': 300,
#   'name': 'npc_dota_hero_skeleton_king',
#   'primary_attr': 'str',
#   'pro_ban': 9,
#   'pro_pick': 15,
#   'pro_win': 8,
#   'projectile_speed': 0,
#   'roles': ['Carry', 'Support', 'Durable', 'Disabler', 'Initiator'],
#   'str_gain': 2.8,
#   'turn_rate': 0.5},
#  {'1000_pick': 2276,
#   '1000_win': 1095,
#   '2000_pick': 4421,
#   '2000_win': 2058,
#   '3000_pick': 4806,
#   '3000_win': 2226,
#   '4000_pick': 1492,
#   '4000_win': 721,
#   '5000_pick': 250,
#   '5000_win': 118,
#   'agi_gain': 1.4,
#   'attack_range': 600,
#   'attack_rate': 1.7,
#   'attack_type': 'Ranged',
#   'base_agi': 14,
#   'base_armor': 1,
#   'base_attack_max': 36,
#   'base_attack_min': 24,
#   'base_health': 200,
#   'base_health_regen': 2,
#   'base_int': 23,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 17,
#   'cm_enabled': True,
#   'hero_id': 43,
#   'icon': '/apps/dota2/images/heroes/death_prophet_icon.png',
#   'id': 43,
#   'img': '/apps/dota2/images/heroes/death_prophet_full.png?',
#   'int_gain': 3,
#   'legs': 2,
#   'localized_name': 'Death Prophet',
#   'move_speed': 310,
#   'name': 'npc_dota_hero_death_prophet',
#   'primary_attr': 'int',
#   'pro_ban': 156,
#   'pro_pick': 146,
#   'pro_win': 72,
#   'projectile_speed': 1000,
#   'roles': ['Carry', 'Pusher', 'Nuker', 'Disabler'],
#   'str_gain': 2.6,
#   'turn_rate': 0.5},
#  {'1000_pick': 17971,
#   '1000_win': 9198,
#   '2000_pick': 35634,
#   '2000_win': 18164,
#   '3000_pick': 37711,
#   '3000_win': 19170,
#   '4000_pick': 10893,
#   '4000_win': 5365,
#   '5000_pick': 1292,
#   '5000_win': 613,
#   'agi_gain': 3.15,
#   'attack_range': 150,
#   'attack_rate': 1.7,
#   'attack_type': 'Melee',
#   'base_agi': 23,
#   'base_armor': 1,
#   'base_attack_max': 25,
#   'base_attack_min': 23,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 15,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 20,
#   'cm_enabled': True,
#   'hero_id': 44,
#   'icon': '/apps/dota2/images/heroes/phantom_assassin_icon.png',
#   'id': 44,
#   'img': '/apps/dota2/images/heroes/phantom_assassin_full.png?',
#   'int_gain': 1.4,
#   'legs': 2,
#   'localized_name': 'Phantom Assassin',
#   'move_speed': 305,
#   'name': 'npc_dota_hero_phantom_assassin',
#   'primary_attr': 'agi',
#   'pro_ban': 38,
#   'pro_pick': 66,
#   'pro_win': 35,
#   'projectile_speed': 900,
#   'roles': ['Carry', 'Escape'],
#   'str_gain': 2.15,
#   'turn_rate': 0.6},
#  {'1000_pick': 3949,
#   '1000_win': 1849,
#   '2000_pick': 9639,
#   '2000_win': 4465,
#   '3000_pick': 13616,
#   '3000_win': 6431,
#   '4000_pick': 5309,
#   '4000_win': 2571,
#   '5000_pick': 888,
#   '5000_win': 425,
#   'agi_gain': 1,
#   'attack_range': 630,
#   'attack_rate': 1.7,
#   'attack_type': 'Ranged',
#   'base_agi': 16,
#   'base_armor': -1,
#   'base_attack_max': 27,
#   'base_attack_min': 19,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 26,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 17,
#   'cm_enabled': True,
#   'hero_id': 45,
#   'icon': '/apps/dota2/images/heroes/pugna_icon.png',
#   'id': 45,
#   'img': '/apps/dota2/images/heroes/pugna_full.png?',
#   'int_gain': 4.5,
#   'legs': 2,
#   'localized_name': 'Pugna',
#   'move_speed': 335,
#   'name': 'npc_dota_hero_pugna',
#   'primary_attr': 'int',
#   'pro_ban': 81,
#   'pro_pick': 42,
#   'pro_win': 15,
#   'projectile_speed': 900,
#   'roles': ['Nuker', 'Pusher'],
#   'str_gain': 1.5,
#   'turn_rate': 0.5},
#  {'1000_pick': 3140,
#   '1000_win': 1321,
#   '2000_pick': 6622,
#   '2000_win': 2815,
#   '3000_pick': 7793,
#   '3000_win': 3358,
#   '4000_pick': 2742,
#   '4000_win': 1220,
#   '5000_pick': 587,
#   '5000_win': 291,
#   'agi_gain': 2.3,
#   'attack_range': 140,
#   'attack_rate': 1.7,
#   'attack_type': 'Ranged',
#   'base_agi': 23,
#   'base_armor': 1,
#   'base_attack_max': 36,
#   'base_attack_min': 30,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 20,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 18,
#   'cm_enabled': True,
#   'hero_id': 46,
#   'icon': '/apps/dota2/images/heroes/templar_assassin_icon.png',
#   'id': 46,
#   'img': '/apps/dota2/images/heroes/templar_assassin_full.png?',
#   'int_gain': 2,
#   'legs': 2,
#   'localized_name': 'Templar Assassin',
#   'move_speed': 300,
#   'name': 'npc_dota_hero_templar_assassin',
#   'primary_attr': 'agi',
#   'pro_ban': 52,
#   'pro_pick': 50,
#   'pro_win': 27,
#   'projectile_speed': 900,
#   'roles': ['Carry', 'Escape'],
#   'str_gain': 2.4,
#   'turn_rate': 0.7},
#  {'1000_pick': 8536,
#   '1000_win': 4189,
#   '2000_pick': 16948,
#   '2000_win': 8390,
#   '3000_pick': 18646,
#   '3000_win': 9376,
#   '4000_pick': 5985,
#   '4000_win': 2987,
#   '5000_pick': 867,
#   '5000_win': 441,
#   'agi_gain': 2.9,
#   'attack_range': 575,
#   'attack_rate': 1.7,
#   'attack_type': 'Ranged',
#   'base_agi': 21,
#   'base_armor': -2,
#   'base_attack_max': 25,
#   'base_attack_min': 23,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 15,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 20,
#   'cm_enabled': True,
#   'hero_id': 47,
#   'icon': '/apps/dota2/images/heroes/viper_icon.png',
#   'id': 47,
#   'img': '/apps/dota2/images/heroes/viper_full.png?',
#   'int_gain': 1.8,
#   'legs': 0,
#   'localized_name': 'Viper',
#   'move_speed': 275,
#   'name': 'npc_dota_hero_viper',
#   'primary_attr': 'agi',
#   'pro_ban': 237,
#   'pro_pick': 79,
#   'pro_win': 35,
#   'projectile_speed': 1200,
#   'roles': ['Carry', 'Durable', 'Initiator', 'Disabler'],
#   'str_gain': 2.4,
#   'turn_rate': 0.5},
#  {'1000_pick': 5343,
#   '1000_win': 2839,
#   '2000_pick': 11832,
#   '2000_win': 6376,
#   '3000_pick': 14367,
#   '3000_win': 7757,
#   '4000_pick': 5279,
#   '4000_win': 2857,
#   '5000_pick': 791,
#   '5000_win': 423,
#   'agi_gain': 3.3,
#   'attack_range': 330,
#   'attack_rate': 1.7,
#   'attack_type': 'Ranged',
#   'base_agi': 18,
#   'base_armor': 0,
#   'base_attack_max': 26,
#   'base_attack_min': 20,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 16,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 15,
#   'cm_enabled': True,
#   'hero_id': 48,
#   'icon': '/apps/dota2/images/heroes/luna_icon.png',
#   'id': 48,
#   'img': '/apps/dota2/images/heroes/luna_full.png?',
#   'int_gain': 1.85,
#   'legs': 2,
#   'localized_name': 'Luna',
#   'move_speed': 330,
#   'name': 'npc_dota_hero_luna',
#   'primary_attr': 'agi',
#   'pro_ban': 32,
#   'pro_pick': 48,
#   'pro_win': 30,
#   'projectile_speed': 900,
#   'roles': ['Carry', 'Nuker', 'Pusher'],
#   'str_gain': 2.2,
#   'turn_rate': 0.6},
#  {'1000_pick': 4344,
#   '1000_win': 2292,
#   '2000_pick': 8483,
#   '2000_win': 4352,
#   '3000_pick': 8292,
#   '3000_win': 4265,
#   '4000_pick': 2151,
#   '4000_win': 1066,
#   '5000_pick': 298,
#   '5000_win': 161,
#   'agi_gain': 2.2,
#   'attack_range': 150,
# ...
#   'attack_range': 600,
#   'attack_rate': 1.7,
#   'attack_type': 'Ranged',
#   'base_agi': 13,
#   'base_armor': -2,
#   'base_attack_max': 22,
#   'base_attack_min': 12,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 27,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 19,
#   'cm_enabled': True,
#   'hero_id': 101,
#   'icon': '/apps/dota2/images/heroes/skywrath_mage_icon.png',
#   'id': 101,
#   'img': '/apps/dota2/images/heroes/skywrath_mage_full.png?',
#   'int_gain': 3.6,
#   'legs': 2,
#   'localized_name': 'Skywrath Mage',
#   'move_speed': 330,
#   'name': 'npc_dota_hero_skywrath_mage',
#   'primary_attr': 'int',
#   'pro_ban': 2,
#   'pro_pick': 33,
#   'pro_win': 15,
#   'projectile_speed': 1000,
#   'roles': ['Support', 'Nuker', 'Disabler'],
#   'str_gain': 1.8,
#   'turn_rate': 0.5},
#  {'1000_pick': 2567,
#   '1000_win': 1405,
#   '2000_pick': 5574,
#   '2000_win': 2947,
#   '3000_pick': 6085,
#   '3000_win': 3187,
#   '4000_pick': 2065,
#   '4000_win': 1047,
#   '5000_pick': 316,
#   '5000_win': 158,
#   'agi_gain': 1.5,
#   'attack_range': 150,
#   'attack_rate': 1.7,
#   'attack_type': 'Melee',
#   'base_agi': 17,
#   'base_armor': -1,
#   'base_attack_max': 42,
#   'base_attack_min': 32,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 21,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 23,
#   'cm_enabled': True,
#   'hero_id': 102,
#   'icon': '/apps/dota2/images/heroes/abaddon_icon.png',
#   'id': 102,
#   'img': '/apps/dota2/images/heroes/abaddon_full.png?',
#   'int_gain': 2,
#   'legs': 2,
#   'localized_name': 'Abaddon',
#   'move_speed': 310,
#   'name': 'npc_dota_hero_abaddon',
#   'primary_attr': 'str',
#   'pro_ban': 11,
#   'pro_pick': 20,
#   'pro_win': 13,
#   'projectile_speed': 900,
#   'roles': ['Support', 'Carry', 'Durable'],
#   'str_gain': 2.6,
#   'turn_rate': 0.5},
#  {'1000_pick': 1105,
#   '1000_win': 574,
#   '2000_pick': 2630,
#   '2000_win': 1388,
#   '3000_pick': 3222,
#   '3000_win': 1683,
#   '4000_pick': 1102,
#   '4000_win': 575,
#   '5000_pick': 158,
#   '5000_win': 80,
#   'agi_gain': 1.8,
#   'attack_range': 150,
#   'attack_rate': 1.7,
#   'attack_type': 'Melee',
#   'base_agi': 14,
#   'base_armor': 1,
#   'base_attack_max': 33,
#   'base_attack_min': 23,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 23,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 24,
#   'cm_enabled': True,
#   'hero_id': 103,
#   'icon': '/apps/dota2/images/heroes/elder_titan_icon.png',
#   'id': 103,
#   'img': '/apps/dota2/images/heroes/elder_titan_full.png?',
#   'int_gain': 1.6,
#   'legs': 2,
#   'localized_name': 'Elder Titan',
#   'move_speed': 315,
#   'name': 'npc_dota_hero_elder_titan',
#   'primary_attr': 'str',
#   'pro_ban': 5,
#   'pro_pick': 15,
#   'pro_win': 8,
#   'projectile_speed': 900,
#   'roles': ['Initiator', 'Disabler', 'Nuker', 'Durable'],
#   'str_gain': 2.6,
#   'turn_rate': 0.5},
#  {'1000_pick': 13051,
#   '1000_win': 6335,
#   '2000_pick': 25588,
#   '2000_win': 12072,
#   '3000_pick': 25781,
#   '3000_win': 12071,
#   '4000_pick': 6672,
#   '4000_win': 3175,
#   '5000_pick': 929,
#   '5000_win': 431,
#   'agi_gain': 1.7,
#   'attack_range': 150,
#   'attack_rate': 1.7,
#   'attack_type': 'Melee',
#   'base_agi': 18,
#   'base_armor': 0,
#   'base_attack_max': 39,
#   'base_attack_min': 35,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 20,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 26,
#   'cm_enabled': True,
#   'hero_id': 104,
#   'icon': '/apps/dota2/images/heroes/legion_commander_icon.png',
#   'id': 104,
#   'img': '/apps/dota2/images/heroes/legion_commander_full.png?',
#   'int_gain': 2.2,
#   'legs': 2,
#   'localized_name': 'Legion Commander',
#   'move_speed': 320,
#   'name': 'npc_dota_hero_legion_commander',
#   'primary_attr': 'str',
#   'pro_ban': 46,
#   'pro_pick': 54,
#   'pro_win': 24,
#   'projectile_speed': 900,
#   'roles': ['Carry', 'Disabler', 'Initiator', 'Durable', 'Nuker'],
#   'str_gain': 2.9,
#   'turn_rate': 0.5},
#  {'1000_pick': 3054,
#   '1000_win': 1562,
#   '2000_pick': 6494,
#   '2000_win': 3181,
#   '3000_pick': 7213,
#   '3000_win': 3405,
#   '4000_pick': 2209,
#   '4000_win': 1053,
#   '5000_pick': 272,
#   '5000_win': 111,
#   'agi_gain': 1.3,
#   'attack_range': 700,
#   'attack_rate': 1.7,
#   'attack_type': 'Ranged',
#   'base_agi': 14,
#   'base_armor': 5,
#   'base_attack_max': 9,
#   'base_attack_min': 7,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 22,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 17,
#   'cm_enabled': True,
#   'icon': '/apps/dota2/images/heroes/techies_icon.png',
#   'id': 105,
#   'img': '/apps/dota2/images/heroes/techies_full.png?',
#   'int_gain': 2.9,
#   'legs': 6,
#   'localized_name': 'Techies',
#   'move_speed': 270,
#   'name': 'npc_dota_hero_techies',
#   'primary_attr': 'int',
#   'projectile_speed': 900,
#   'roles': ['Nuker', 'Disabler'],
#   'str_gain': 2.3,
#   'turn_rate': 0.5},
#  {'1000_pick': 3922,
#   '1000_win': 1804,
#   '2000_pick': 9839,
#   '2000_win': 4551,
#   '3000_pick': 12957,
#   '3000_win': 6118,
#   '4000_pick': 4772,
#   '4000_win': 2251,
#   '5000_pick': 876,
#   '5000_win': 398,
#   'agi_gain': 1.8,
#   'attack_range': 150,
#   'attack_rate': 1.7,
#   'attack_type': 'Melee',
#   'base_agi': 22,
#   'base_armor': -2,
#   'base_attack_max': 34,
#   'base_attack_min': 30,
#   'base_health': 200,
#   'base_health_regen': 2,
#   'base_int': 20,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 19,
#   'cm_enabled': True,
#   'hero_id': 106,
#   'icon': '/apps/dota2/images/heroes/ember_spirit_icon.png',
#   'id': 106,
#   'img': '/apps/dota2/images/heroes/ember_spirit_full.png?',
#   'int_gain': 1.8,
#   'legs': 2,
#   'localized_name': 'Ember Spirit',
#   'move_speed': 305,
#   'name': 'npc_dota_hero_ember_spirit',
#   'primary_attr': 'agi',
#   'pro_ban': 48,
#   'pro_pick': 46,
#   'pro_win': 18,
#   'projectile_speed': 900,
#   'roles': ['Carry', 'Escape', 'Nuker', 'Disabler', 'Initiator'],
#   'str_gain': 2.1,
#   'turn_rate': 0.5},
#  {'1000_pick': 1659,
#   '1000_win': 700,
#   '2000_pick': 5283,
#   '2000_win': 2381,
#   '3000_pick': 9836,
#   '3000_win': 4401,
#   '4000_pick': 4984,
#   '4000_win': 2239,
#   '5000_pick': 1266,
#   '5000_win': 638,
#   'agi_gain': 1.5,
#   'attack_range': 150,
#   'attack_rate': 1.7,
#   'attack_type': 'Melee',
#   'base_agi': 17,
#   'base_armor': 1,
#   'base_attack_max': 35,
#   'base_attack_min': 25,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 18,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 21,
#   'cm_enabled': True,
#   'hero_id': 107,
#   'icon': '/apps/dota2/images/heroes/earth_spirit_icon.png',
#   'id': 107,
#   'img': '/apps/dota2/images/heroes/earth_spirit_full.png?',
#   'int_gain': 2.1,
#   'legs': 2,
#   'localized_name': 'Earth Spirit',
#   'move_speed': 290,
#   'name': 'npc_dota_hero_earth_spirit',
#   'primary_attr': 'str',
#   'pro_ban': 214,
#   'pro_pick': 215,
#   'pro_win': 109,
#   'projectile_speed': 900,
#   'roles': ['Nuker', 'Escape', 'Disabler', 'Initiator', 'Durable'],
#   'str_gain': 3.2,
#   'turn_rate': 0.6},
#  {'1000_pick': 2142,
#   '1000_win': 1187,
#   '2000_pick': 5605,
#   '2000_win': 3111,
#   '3000_pick': 7532,
#   '3000_win': 4191,
#   '4000_pick': 3122,
#   '4000_win': 1721,
#   '5000_pick': 541,
#   '5000_win': 268,
#   'agi_gain': 1.3,
#   'attack_range': 150,
#   'attack_rate': 1.7,
#   'attack_type': 'Melee',
#   'base_agi': 12,
#   'base_armor': 2,
#   'base_attack_max': 43,
#   'base_attack_min': 37,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 17,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 25,
#   'cm_enabled': True,
#   'hero_id': 108,
#   'icon': '/apps/dota2/images/heroes/abyssal_underlord_icon.png',
#   'id': 108,
#   'img': '/apps/dota2/images/heroes/abyssal_underlord_full.png?',
#   'int_gain': 2.6,
#   'legs': 2,
#   'localized_name': 'Underlord',
#   'move_speed': 290,
#   'name': 'npc_dota_hero_abyssal_underlord',
#   'primary_attr': 'str',
#   'pro_ban': 30,
#   'pro_pick': 55,
#   'pro_win': 34,
#   'projectile_speed': 900,
#   'roles': ['Support', 'Nuker', 'Disabler', 'Durable', 'Escape'],
#   'str_gain': 2.9,
#   'turn_rate': 0.6},
#  {'1000_pick': 2496,
#   '1000_win': 1246,
#   '2000_pick': 5552,
#   '2000_win': 2831,
#   '3000_pick': 6865,
#   '3000_win': 3569,
#   '4000_pick': 2434,
#   '4000_win': 1246,
#   '5000_pick': 446,
#   '5000_win': 244,
#   'agi_gain': 3.2,
#   'attack_range': 150,
#   'attack_rate': 1.5,
#   'attack_type': 'Melee',
#   'base_agi': 22,
#   'base_armor': 7,
#   'base_attack_max': 32,
#   'base_attack_min': 26,
#   'base_health': 200,
#   'base_health_regen': 3.25,
#   'base_int': 19,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 15,
#   'cm_enabled': True,
#   'hero_id': 109,
#   'icon': '/apps/dota2/images/heroes/terrorblade_icon.png',
#   'id': 109,
#   'img': '/apps/dota2/images/heroes/terrorblade_full.png?',
#   'int_gain': 1.6,
#   'legs': 2,
#   'localized_name': 'Terrorblade',
#   'move_speed': 310,
#   'name': 'npc_dota_hero_terrorblade',
#   'primary_attr': 'agi',
#   'pro_ban': 94,
#   'pro_pick': 70,
#   'pro_win': 38,
#   'projectile_speed': 900,
#   'roles': ['Carry', 'Pusher', 'Nuker'],
#   'str_gain': 1.7,
#   'turn_rate': 0.5},
#  {'1000_pick': 2000,
#   '1000_win': 964,
#   '2000_pick': 5532,
#   '2000_win': 2787,
#   '3000_pick': 7655,
#   '3000_win': 3749,
#   '4000_pick': 3179,
#   '4000_win': 1579,
#   '5000_pick': 513,
#   '5000_win': 236,
#   'agi_gain': 1.3,
#   'attack_range': 500,
#   'attack_rate': 1.7,
#   'attack_type': 'Ranged',
#   'base_agi': 12,
#   'base_armor': -2,
#   'base_attack_max': 36,
#   'base_attack_min': 26,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 18,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 19,
#   'cm_enabled': True,
#   'hero_id': 110,
#   'icon': '/apps/dota2/images/heroes/phoenix_icon.png',
#   'id': 110,
#   'img': '/apps/dota2/images/heroes/phoenix_full.png?',
#   'int_gain': 1.8,
#   'legs': 2,
#   'localized_name': 'Phoenix',
#   'move_speed': 285,
#   'name': 'npc_dota_hero_phoenix',
#   'primary_attr': 'str',
#   'pro_ban': 2,
#   'pro_pick': 13,
#   'pro_win': 3,
#   'projectile_speed': 1100,
#   'roles': ['Support', 'Nuker', 'Initiator', 'Escape', 'Disabler'],
#   'str_gain': 3.2,
#   'turn_rate': 1},
#  {'1000_pick': 866,
#   '1000_win': 367,
#   '2000_pick': 2356,
#   '2000_win': 964,
#   '3000_pick': 3401,
#   '3000_win': 1480,
#   '4000_pick': 1441,
#   '4000_win': 700,
#   '5000_pick': 339,
#   '5000_win': 159,
#   'agi_gain': 1.7,
#   'attack_range': 620,
#   'attack_rate': 1.4,
#   'attack_type': 'Ranged',
#   'base_agi': 15,
#   'base_armor': 0,
#   'base_attack_max': 22,
#   'base_attack_min': 16,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 23,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 18,
#   'cm_enabled': True,
#   'hero_id': 111,
#   'icon': '/apps/dota2/images/heroes/oracle_icon.png',
#   'id': 111,
#   'img': '/apps/dota2/images/heroes/oracle_full.png?',
#   'int_gain': 2.9,
#   'legs': 2,
#   'localized_name': 'Oracle',
#   'move_speed': 305,
#   'name': 'npc_dota_hero_oracle',
#   'primary_attr': 'int',
#   'pro_ban': 12,
#   'pro_pick': 23,
#   'pro_win': 15,
#   'projectile_speed': 900,
#   'roles': ['Support', 'Nuker', 'Disabler', 'Escape'],
#   'str_gain': 2.2,
#   'turn_rate': 0.5},
#  {'1000_pick': 2284,
#   '1000_win': 1108,
#   '2000_pick': 6158,
#   '2000_win': 3042,
#   '3000_pick': 9202,
#   '3000_win': 4553,
#   '4000_pick': 3776,
#   '4000_win': 1927,
#   '5000_pick': 888,
#   '5000_win': 464,
#   'agi_gain': 1.9,
#   'attack_range': 425,
#   'attack_rate': 1.7,
#   'attack_type': 'Ranged',
#   'base_agi': 16,
#   'base_armor': -1,
#   'base_attack_max': 17,
#   'base_attack_min': 10,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 25,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 24,
#   'cm_enabled': True,
#   'hero_id': 112,
#   'icon': '/apps/dota2/images/heroes/winter_wyvern_icon.png',
#   'id': 112,
#   'img': '/apps/dota2/images/heroes/winter_wyvern_full.png?',
#   'int_gain': 3.1,
#   'legs': 2,
#   'localized_name': 'Winter Wyvern',
#   'move_speed': 285,
#   'name': 'npc_dota_hero_winter_wyvern',
#   'primary_attr': 'int',
#   'pro_ban': 303,
#   'pro_pick': 200,
#   'pro_win': 121,
#   'projectile_speed': 700,
#   'roles': ['Support', 'Disabler', 'Nuker'],
#   'str_gain': 2.4,
#   'turn_rate': 0.5},
#  {'1000_pick': 1258,
#   '1000_win': 530,
#   '2000_pick': 3024,
#   '2000_win': 1358,
#   '3000_pick': 4117,
#   '3000_win': 1937,
#   '4000_pick': 1782,
#   '4000_win': 878,
#   '5000_pick': 356,
#   '5000_win': 162,
#   'agi_gain': 1.8,
#   'attack_range': 625,
#   'attack_rate': 1.7,
#   'attack_type': 'Ranged',
#   'base_agi': 15,
#   'base_armor': -2,
#   'base_attack_max': 39,
#   'base_attack_min': 29,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 24,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 24,
#   'cm_enabled': True,
#   'hero_id': 113,
#   'icon': '/apps/dota2/images/heroes/arc_warden_icon.png',
#   'id': 113,
#   'img': '/apps/dota2/images/heroes/arc_warden_full.png?',
#   'int_gain': 2.6,
#   'legs': 2,
#   'localized_name': 'Arc Warden',
#   'move_speed': 280,
#   'name': 'npc_dota_hero_arc_warden',
#   'primary_attr': 'agi',
#   'pro_ban': 17,
#   'pro_pick': 12,
#   'pro_win': 7,
#   'projectile_speed': 900,
#   'roles': ['Carry', 'Escape', 'Nuker'],
#   'str_gain': 3,
#   'turn_rate': 0.6},
#  {'1000_pick': 9558,
#   '1000_win': 4378,
#   '2000_pick': 21802,
#   '2000_win': 9968,
#   '3000_pick': 29355,
#   '3000_win': 13353,
#   '4000_pick': 11270,
#   '4000_win': 5344,
#   '5000_pick': 2251,
#   '5000_win': 1051,
#   'agi_gain': 3.2,
#   'attack_range': 300,
#   'attack_rate': 1.7,
#   'attack_type': 'Melee',
#   'base_agi': 22,
#   'base_armor': -3,
#   'base_attack_max': 33,
#   'base_attack_min': 27,
#   'base_health': 200,
#   'base_health_regen': 3,
#   'base_int': 20,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 18,
#   'cm_enabled': True,
#   'hero_id': 114,
#   'icon': '/apps/dota2/images/heroes/monkey_king_icon.png',
#   'id': 114,
#   'img': '/apps/dota2/images/heroes/monkey_king_full.png?',
#   'int_gain': 1.8,
#   'legs': 2,
#   'localized_name': 'Monkey King',
#   'move_speed': 300,
#   'name': 'npc_dota_hero_monkey_king',
#   'primary_attr': 'agi',
#   'pro_ban': 102,
#   'pro_pick': 93,
#   'pro_win': 51,
#   'projectile_speed': 900,
#   'roles': ['Carry', 'Escape', 'Disabler', 'Initiator'],
#   'str_gain': 2.8,
#   'turn_rate': 0.6},
#  {'1000_pick': 6259,
#   '1000_win': 2915,
#   '2000_pick': 14876,
#   '2000_win': 7108,
#   '3000_pick': 19943,
#   '3000_win': 9750,
#   '4000_pick': 7329,
#   '4000_win': 3706,
#   '5000_pick': 1222,
#   '5000_win': 661,
#   'agi_gain': 1.6,
#   'attack_range': 475,
#   'attack_rate': 1.3,
#   'attack_type': 'Ranged',
#   'base_agi': 18,
#   'base_armor': -1,
#   'base_attack_max': 33,
#   'base_attack_min': 25,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 20,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 18,
#   'cm_enabled': True,
#   'icon': '/apps/dota2/images/heroes/dark_willow_icon.png',
#   'id': 119,
#   'img': '/apps/dota2/images/heroes/dark_willow_full.png?',
#   'int_gain': 3,
#   'legs': 2,
#   'localized_name': 'Dark Willow',
#   'move_speed': 295,
#   'name': 'npc_dota_hero_dark_willow',
#   'primary_attr': 'int',
#   'projectile_speed': 1200,
#   'roles': ['Support', 'Nuker', 'Disabler', 'Escape'],
#   'str_gain': 1.8,
#   'turn_rate': 0.7},
#  {'1000_pick': 6649,
#   '1000_win': 2781,
#   '2000_pick': 15610,
#   '2000_win': 6391,
#   '3000_pick': 20345,
#   '3000_win': 8313,
#   '4000_pick': 7773,
#   '4000_win': 3325,
#   '5000_pick': 1386,
#   '5000_win': 600,
#   'agi_gain': 2.8,
#   'attack_range': 150,
#   'attack_rate': 1.7,
#   'attack_type': 'Melee',
#   'base_agi': 18,
#   'base_armor': 1,
#   'base_attack_max': 35,
#   'base_attack_min': 29,
#   'base_health': 200,
#   'base_health_regen': 1.5,
#   'base_int': 16,
#   'base_mana': 75,
#   'base_mana_regen': 0.9,
#   'base_mr': 25,
#   'base_str': 16,
#   'cm_enabled': True,
#   'icon': '/apps/dota2/images/heroes/pangolier_icon.png',
#   'id': 120,
#   'img': '/apps/dota2/images/heroes/pangolier_full.png?',
#   'int_gain': 1.9,
#   'legs': 2,
#   'localized_name': 'Pangolier',
#   'move_speed': 305,
#   'name': 'npc_dota_hero_pangolier',
#   'primary_attr': 'agi',
#   'projectile_speed': 900,
#   'roles': ['Carry', 'Nuker', 'Disabler', 'Durable', 'Escape', 'Initiator'],
#   'str_gain': 2.5,
#   'turn_rate': 1}]

# %%
api_url = "https://api.opendota.com/api/benchmarks?hero_id=107"

# %%
r = rq.get(api_url)

# %%
content = r.content
soup = BeautifulSoup(content, "html5lib")

# %%
r.json()
# Out:
# {'hero_id': 107,
#  'result': {'gold_per_min': [{'percentile': 0.1, 'value': 182},
#    {'percentile': 0.2, 'value': 209},
#    {'percentile': 0.3, 'value': 241},
#    {'percentile': 0.4, 'value': 271},
#    {'percentile': 0.5, 'value': 286},
#    {'percentile': 0.6, 'value': 307},
#    {'percentile': 0.7, 'value': 319},
#    {'percentile': 0.8, 'value': 355},
#    {'percentile': 0.9, 'value': 385},
#    {'percentile': 0.95, 'value': 405},
#    {'percentile': 0.99, 'value': 457}],
#   'hero_damage_per_min': [{'percentile': 0.1, 'value': 130.74098360655736},
#    {'percentile': 0.2, 'value': 170.17521503663588},
#    {'percentile': 0.3, 'value': 202.80862181580665},
#    {'percentile': 0.4, 'value': 225.06588579795022},
#    {'percentile': 0.5, 'value': 250.7556018759771},
#    {'percentile': 0.6, 'value': 272.31633130556855},
#    {'percentile': 0.7, 'value': 296.2914364640884},
#    {'percentile': 0.8, 'value': 326.5371684721703},
#    {'percentile': 0.9, 'value': 400.94262295081967},
#    {'percentile': 0.95, 'value': 462.7772020725389},
#    {'percentile': 0.99, 'value': 578.3614656237135}],
#   'hero_healing_per_min': [{'percentile': 0.1, 'value': 0},
#    {'percentile': 0.2, 'value': 0},
#    {'percentile': 0.3, 'value': 0},
#    {'percentile': 0.4, 'value': 0},
#    {'percentile': 0.5, 'value': 0},
#    {'percentile': 0.6, 'value': 0},
#    {'percentile': 0.7, 'value': 0},
#    {'percentile': 0.8, 'value': 0},
#    {'percentile': 0.9, 'value': 0},
#    {'percentile': 0.95, 'value': 0},
#    {'percentile': 0.99, 'value': 5.277973258268824}],
#   'kills_per_min': [{'percentile': 0.1, 'value': 0},
#    {'percentile': 0.2, 'value': 0.02707581227436823},
#    {'percentile': 0.3, 'value': 0.044859813084112146},
#    {'percentile': 0.4, 'value': 0.07290400972053462},
#    {'percentile': 0.5, 'value': 0.08275862068965517},
#    {'percentile': 0.6, 'value': 0.0966702470461869},
#    {'percentile': 0.7, 'value': 0.11244377811094453},
#    {'percentile': 0.8, 'value': 0.13447889428464702},
#    {'percentile': 0.9, 'value': 0.1700921332388377},
#    {'percentile': 0.95, 'value': 0.2097902097902098},
#    {'percentile': 0.99, 'value': 0.2903560318008987}],
#   'last_hits_per_min': [{'percentile': 0.1, 'value': 0.34211240836274776},
#    {'percentile': 0.2, 'value': 0.5593922651933702},
#    {'percentile': 0.3, 'value': 0.7269155206286837},
#    {'percentile': 0.4, 'value': 0.8488278092158448},
#    {'percentile': 0.5, 'value': 0.9604268563806138},
#    {'percentile': 0.6, 'value': 1.0432033719704952},
#    {'percentile': 0.7, 'value': 1.2019491066594477},
#    {'percentile': 0.8, 'value': 1.4414923685698136},
#    {'percentile': 0.9, 'value': 1.7207929143821172},
#    {'percentile': 0.95, 'value': 1.882885797476545},
#    {'percentile': 0.99, 'value': 2.9161603888213854}],
#   'tower_damage': [{'percentile': 0.1, 'value': 0},
#    {'percentile': 0.2, 'value': 0},
#    {'percentile': 0.3, 'value': 0},
#    {'percentile': 0.4, 'value': 13},
#    {'percentile': 0.5, 'value': 56},
#    {'percentile': 0.6, 'value': 119},
#    {'percentile': 0.7, 'value': 239},
#    {'percentile': 0.8, 'value': 439},
#    {'percentile': 0.9, 'value': 719},
#    {'percentile': 0.95, 'value': 976},
#    {'percentile': 0.99, 'value': 1691}],
#   'xp_per_min': [{'percentile': 0.1, 'value': 217},
#    {'percentile': 0.2, 'value': 272},
#    {'percentile': 0.3, 'value': 320},
#    {'percentile': 0.4, 'value': 360},
#    {'percentile': 0.5, 'value': 398},
#    {'percentile': 0.6, 'value': 426},
#    {'percentile': 0.7, 'value': 453},
#    {'percentile': 0.8, 'value': 510},
#    {'percentile': 0.9, 'value': 558},
#    {'percentile': 0.95, 'value': 587},
#    {'percentile': 0.99, 'value': 648}]}}

# %%
api_url = "https://api.opendota.com/api/benchmarks?hero_id=8"
r = rq.get(api_url)
content = r.content
soup = BeautifulSoup(content, "html5lib")
r.json()
